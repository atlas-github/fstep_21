# %% [markdown]
# <a href="https://colab.research.google.com/github/atlas-github/fstep_21/blob/main/fstep_21_banknegara_solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Use Postman to generate the Python code to get Latest Exchange Rates from [here](https://api.bnm.gov.my/explorer?category=Rates%20and%20Volumes)

# %%
import requests

url = "https://api.bnm.gov.my/public/exchange-rate"

payload={}
headers = {
  'Accept': 'application/vnd.BNM.API.v1+json',
  'Cookie': 'TS01c7b99f=0152d1c092b30c5e49d858830f77a6b78e47eaa39ff6ce2d977ff5a3ffa85788609d2f1c56fb251d4c2b1332ba83fab2592bdc5741'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"data":[{"currency_code":"CHF","unit":1,"rate":{"date":"2021-11-02","buying_rate":4.5481,"selling_rate":4.5524,"middle_rate":4.5503}},{"currency_code":"CAD","unit":1,"rate":{"date":"2021-11-02","buying_rate":3.3427,"selling_rate":3.3454,"middle_rate":3.3441}},{"currency_code":"BND","unit":1,"rate":{"date":"2021-11-02","buying_rate":3.076,"selling_rate":3.0789,"middle_rate":3.0774}},{"currency_code":"AUD","unit":1,"rate":{"date":"2021-11-02","buying_rate":3.0945,"selling_rate":3.0976,"middle_rate":3.096}},{"currency_code":"AED","unit":100,"rate":{"date":"2021-11-02","buying_rate":112.8835,"selling_rate":112.999,"middle_rate":112.9412}},{"currency_code":"CNY","unit":1,"rate":{"date":"2021-11-02","buying_rate":0.6483,"selling_rate":0.6488,"middle_rate":0.6485}},{"currency_code":"NPR","unit":100,"rate":{"date":"2021-11-02","buying_rate":3.4651,"selling_rate":3.4682,"middle_rate":3.4666}},{"currency_code":"SDR","unit":1,"rate":{"date":"2021-11-02","buying_rate":null,"selling_rate":null,"
# ...

# %%
response.json()['data']
# Out:
# [{'currency_code': 'CHF',
#   'rate': {'buying_rate': 4.5481,
#    'date': '2021-11-02',
#    'middle_rate': 4.5503,
#    'selling_rate': 4.5524},
#   'unit': 1},
#  {'currency_code': 'CAD',
#   'rate': {'buying_rate': 3.3427,
#    'date': '2021-11-02',
#    'middle_rate': 3.3441,
#    'selling_rate': 3.3454},
#   'unit': 1},
#  {'currency_code': 'BND',
#   'rate': {'buying_rate': 3.076,
#    'date': '2021-11-02',
#    'middle_rate': 3.0774,
#    'selling_rate': 3.0789},
#   'unit': 1},
#  {'currency_code': 'AUD',
#   'rate': {'buying_rate': 3.0945,
#    'date': '2021-11-02',
#    'middle_rate': 3.096,
#    'selling_rate': 3.0976},
#   'unit': 1},
#  {'currency_code': 'AED',
#   'rate': {'buying_rate': 112.8835,
#    'date': '2021-11-02',
#    'middle_rate': 112.9412,
#    'selling_rate': 112.999},
#   'unit': 100},
#  {'currency_code': 'CNY',
#   'rate': {'buying_rate': 0.6483,
#    'date': '2021-11-02',
#    'middle_rate': 0.6485,
#    'selling_rate': 0.6488},
#   'unit': 1},
# ...

# %%
import json

a_json = json.loads(response.text)
dataframe = pd.json_normalize(a_json["data"])
dataframe
# Out:
#    currency_code  unit  ... rate.selling_rate  rate.middle_rate
# 0            CHF     1  ...            4.5524            4.5503
# 1            CAD     1  ...            3.3454            3.3441
# 2            BND     1  ...            3.0789            3.0774
# 3            AUD     1  ...            3.0976            3.0960
# 4            AED   100  ...          112.9990          112.9412
# 5            CNY     1  ...            0.6488            0.6485
# 6            NPR   100  ...            3.4682            3.4666
# 7            SDR     1  ...               NaN            5.8528
# 8            VND   100  ...            0.0182            0.0182
# 9            USD     1  ...            4.1500            4.1485
# 10           TWD   100  ...           14.8970           14.8889
# 11           THB   100  ...           12.4850           12.4767
# 12           SGD     1  ...            3.0786            3.0774
# 13           SAR   100  ...          110.6372          110.5942
# ...

# %% [markdown]
# #Exercise: Get Overnight Policy Rate (OPR) from 2015 [here](https://api.bnm.gov.my/explorer?category=Rates%20and%20Volumes), then output as a table

# %%
import requests

url = "https://api.bnm.gov.my/public/opr/year/2015"

payload={}
headers = {
  'Accept': 'application/vnd.BNM.API.v1+json',
  'Cookie': 'TS01c7b99f=0152d1c092fbaee92374622be627ee6681055adc8939de4d4dd8ee33afec07213f28db1789893514b54632f46c045793cd34549645'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"data":[{"year":2015,"date":"2015-11-05","change_in_opr":0,"new_opr_level":3.25},{"year":2015,"date":"2015-09-11","change_in_opr":0,"new_opr_level":3.25},{"year":2015,"date":"2015-07-09","change_in_opr":0,"new_opr_level":3.25},{"year":2015,"date":"2015-05-07","change_in_opr":0,"new_opr_level":3.25},{"year":2015,"date":"2015-03-05","change_in_opr":0,"new_opr_level":3.25},{"year":2015,"date":"2015-01-28","change_in_opr":0,"new_opr_level":3.25}],"meta":{"last_updated":"2020-09-18 08:54:33","total_result":6}}

# %%
b_json = json.loads(response.text)
df2 = pd.json_normalize(b_json["data"])
df2
# Out:
#    year        date  change_in_opr  new_opr_level
# 0  2015  2015-11-05              0           3.25
# 1  2015  2015-09-11              0           3.25
# 2  2015  2015-07-09              0           3.25
# 3  2015  2015-05-07              0           3.25
# 4  2015  2015-03-05              0           3.25
# 5  2015  2015-01-28              0           3.25
